# %% [markdown]
# # use this to solve start mongodb
# http://www.marcusoft.net/2014/05/mongodb-and-10309-unable-to-createopen.html

# %%
#DB SETUP

from pymongo import MongoClient


import pprint
client = MongoClient('mongodb://localhost:27017')
db = client.musicfan

# %% [markdown]
# creat instance and insert data   ||json format description http://dataprotocols.org/json-table-schema/

# %% [markdown]
# # CRUD function for recommendation system
# In MongoDB, the primary key is automatically created and assigned to the _id field. If you do not specify the _id field, it will be auto-generated for you. The _id field is always indexed and always unique.
# You can't change this, the behaviour is baked in to MongoDB.

# %%
#CRUD functionality for recommendation system

def user_create(uid,name,email,pw):
    #schema for user instance
    #UID name email pw 
    #email should be unique
    '''
    input:
    uid = 0
    name = 'john'
    email = 'john@gmail.com'
    pw = 'john1111'
    '''
    User={
    "UID":uid,
    "Name":name,
    "Email":email,
    "PW":pw
    }
    db.user.insert(User)

#db.user.create_index(("Email"),unique=True)


def rating_create(UID,ItemID,time):
    #schema for rating instance
    #UID ItemID rating   (UID and ItemID is primary key)
    # here I set a initial for UID ItemID test time, time can be return from the webpage side
    """
    input:
    UID =  32
    ItemID =  0
    time = 1600
    """
    
    if time < 5:
        rating = 0
    elif 5<=time and time < 60:
        rating = 1
    elif 60<=time and time < 120:
        rating = 2    
    elif 120<=time and time < 180:
        rating = 3
    elif 180<=time and time  < 240:
        rating = 4
    elif 240<=time :
        rating = 5    
    Rating = {"UID":UID,
              "ItemID":ItemID,
              "Rating":rating}
    db.rating.insert(Rating)

#db.rating.create_index([("UID", pymongo.ASCENDING),("ItemID", pymongo.ASCENDING)],unique=True)

def item_create(itemID,url,avatar):

    #itemID(primary key) url avatar
    """
    input:
    itemID=10
    url ="https://www.udacity.com/course/viewer#!/c-ud032/l-745498943/m-734730655" 
    tn = "http://lh3.ggpht.com/ll9ungBQPIwG1u5WHYyB_q-CO6gAzJC-fT3xotaS5DV3UbNZ7Xdz6b5T3Jpl7aEfmVEY2gjvkkt7KzWVeIo=s0"
    """
    Item = {
    "ItemID":itemID,
    "Url":url,
    "Thumbnail":tn
    }
    db.item.insert(Item)

#db.item.create_index(("ItemID"),unique=True)

# %% [markdown]
# query in db, notice when we do collaborative filtering, we only need to convert the rating instance from json to csv for graphlab to conduct the computing for the CF matrix. In this context, we only care about query item that we can retrieve to send to recommendation system rendering side.

# %%
#Query in db, notice when we do collaborative filtering, we only need to convert 
#the rating instance from json to csv for graphlab to conduct the computing for the CF matrix. 
#In this context, we only care about query item that we can retrieve to send to recommendation system rendering side.
def find_item(itemID):
    item =  db.item.find({"ItemID":itemID})
    
    return item
find_item(10)

# %% [markdown]
# update db

# %%
def user_update(uid,name=None,email=None,pw=None):
    User = db.user.find_one({"UID":uid})
    if ((name and email and pw )is None):
        raise IOError("Nothing to update.")
    if (name is not None):
        User["Name"] = name
    if (email is not None):
        User["Email"] = email
    if (pw is not None):
        User["PW"]=pw
def item_update(itemID,url=None,avatar=None):
    User = db.item.find_one({"ItemID":itemID})
    if ((url and avartar)is None):
        raise IOError("Nothing to update.")
    if (url is not None):
        User["Url"] = url
    if (avatar is not None):
        User["Avatar"] = avatar
    

def rating_update(uid,itemID,rating):
    User = db.rating.find_one({"UID":uid, "ItemID":itemID})
    User["Rating"]=rating

# %%
#For the remove option, since we value all the info we saved here, this option will be implemented when needed.
#Be careful when remove all, this will cause your entire data lost.
def item_remove_all():
    """
    remove all item in db
    """
    db.item.drop()
def user_remove_all():
    """
    remove all user in db
    """
    db.user.drop() 
def rating_remove_all():
    """
    remove all rating in db
    """
    db.rating.drop()

# %%
#test another problem is the id problem, unique find in mongodb

itemID=10
url ="https://www.udacity.com/course/viewer#!/c-ud032/l-745498943/m-734730655" 
tn = "http://lh3.ggpht.com/ll9ungBQPIwG1u5WHYyB_q-CO6gAzJC-fT3xotaS5DV3UbNZ7Xdz6b5T3Jpl7aEfmVEY2gjvkkt7KzWVeIo=s0"
item_create(itemID,url,tn)

type(db.rating)
for a in db.rating.find():
    pprint.pprint(a)
'''
rating_remove_all()
'''
# Out:
# {u'ItemID': 6327,
#  u'Rating': 0,
#  u'UID': 48,
#  u'_id': ObjectId('552be72037902f028450cb8c')}
# {u'ItemID': 3634,
#  u'Rating': 5,
#  u'UID': 522,
#  u'_id': ObjectId('552be74837902f028450cb8d')}
# {u'ItemID': 289,
#  u'Rating': 5,
#  u'UID': 469,
#  u'_id': ObjectId('552be74837902f028450cb8e')}
# {u'ItemID': 5503,
#  u'Rating': 5,
#  u'UID': 171,
#  u'_id': ObjectId('552be74837902f028450cb8f')}
# {u'ItemID': 9465,
#  u'Rating': 5,
#  u'UID': 76,
#  u'_id': ObjectId('552be74837902f028450cb90')}
# {u'ItemID': 2765,
#  u'Rating': 5,
#  u'UID': 164,
#  u'_id': ObjectId('552be74837902f028450cb91')}
# {u'ItemID': 6071,
#  u'Rating': 5,
#  u'UID': 408,
#  u'_id': ObjectId('552be74837902f028450cb92')}
# {u'ItemID': 2120,
#  u'Rating': 5,
#  u'UID': 150,
#  u'_id': ObjectId('552be74837902f028450cb93')}
# {u'ItemID': 8077,
#  u'Rating': 5,
#  u'UID': 849,
#  u'_id': ObjectId('552be74837902f028450cb94')}
# {u'ItemID': 1405,
#  u'Rating': 5,
#  u'UID': 602,
#  u'_id': ObjectId('552be74837902f028450cb95')}
# {u'ItemID': 3247,
#  u'Rating': 5,
#  u'UID': 144,
#  u'_id': ObjectId('552be74837902f028450cb96')}
# {u'ItemID': 4226,
#  u'Rating': 5,
#  u'UID': 497,
#  u'_id': ObjectId('552be74837902f028450cb97')}
# {u'ItemID': 2065,
#  u'Rating': 5,
#  u'UID': 601,
#  u'_id': ObjectId('552be74837902f028450cb98')}
# {u'ItemID': 3386,
#  u'Rating': 5,
#  u'UID': 601,
#  u'_id': ObjectId('552be74837902f028450cb99')}
# {u'ItemID': 7842,
#  u'Rating': 5,
#  u'UID': 585,
#  u'_id': ObjectId('552be74837902f028450cb9a')}
# {u'ItemID': 7268,
#  u'Rating': 5,
#  u'UID': 999,
#  u'_id': ObjectId('552be74837902f028450cb9b')}
# {u'ItemID': 6,
#  u'Rating': 5,
#  u'UID': 741,
#  u'_id': ObjectId('552be74837902f028450cb9c')}
# {u'ItemID': 4555,
#  u'Rating': 5,
#  u'UID': 400,
#  u'_id': ObjectId('552be74837902f028450cb9d')}
# {u'ItemID': 69,
#  u'Rating': 5,
#  u'UID': 851,
#  u'_id': ObjectId('552be74837902f028450cb9e')}
# {u'ItemID': 5269,
#  u'Rating': 5,
#  u'UID': 460,
#  u'_id': ObjectId('552be74837902f028450cb9f')}
# {u'ItemID': 7325,
#  u'Rating': 5,
#  u'UID': 563,
#  u'_id': ObjectId('552be74837902f028450cba0')}
# {u'ItemID': 4054,
#  u'Rating': 5,
#  u'UID': 464,
#  u'_id': ObjectId('552be74837902f028450cba1')}
# {u'ItemID': 3832,
#  u'Rating': 5,
#  u'UID': 834,
#  u'_id': ObjectId('552be74837902f028450cba2')}
# {u'ItemID': 12,
#  u'Rating': 5,
#  u'UID': 504,
#  u'_id': ObjectId('552be74837902f028450cba3')}
# {u'ItemID': 2,
#  u'Rating': 5,
#  u'UID': 857,
#  u'_id': ObjectId('552be74837902f028450cba4')}
# {u'ItemID': 2422,
#  u'Rating': 5,
#  u'UID': 305,
#  u'_id': ObjectId('552be74837902f028450cba5')}
# {u'ItemID': 6275,
#  u'Rating': 5,
#  u'UID': 601,
#  u'_id': ObjectId('552be74837902f028450cba6')}
# {u'ItemID': 4888,
#  u'Rating': 5,
#  u'UID': 283,
#  u'_id': ObjectId('552be74837902f028450cba7')}
# {u'ItemID': 2983,
#  u'Rating': 5,
#  u'UID': 365,
#  u'_id': ObjectId('552be74837902f028450cba8')}
# {u'ItemID': 5456,
#  u'Rating': 5,
#  u'UID': 595,
#  u'_id': ObjectId('552be74837902f028450cba9')}
# {u'ItemID': 8456,
#  u'Rating': 5,
#  u'UID': 230,
#  u'_id': ObjectId('552be74837902f028450cbaa')}
# {u'ItemID': 5140,
#  u'Rating': 5,
#  u'UID': 871,
#  u'_id': ObjectId('552be74837902f028450cbab')}
# {u'ItemID': 4203,
#  u'Rating': 5,
#  u'UID': 928,
#  u'_id': ObjectId('552be74837902f028450cbac')}
# {u'ItemID': 5708,
#  u'Rating': 5,
#  u'UID': 418,
#  u'_id': ObjectId('552be74837902f028450cbad')}
# {u'ItemID': 7775,
#  u'Rating': 5,
#  u'UID': 639,
#  u'_id': ObjectId('552be74837902f028450cbae')}
# {u'ItemID': 1740,
#  u'Rating': 5,
#  u'UID': 765,
#  u'_id': ObjectId('552be74837902f028450cbaf')}
# {u'ItemID': 7303,
#  u'Rating': 5,
#  u'UID': 708,
#  u'_id': ObjectId('552be74837902f028450cbb0')}
# {u'ItemID': 2557,
#  u'Rating': 5,
#  u'UID': 468,
#  u'_id': ObjectId('552be74837902f028450cbb1')}
# {u'ItemID': 4435,
#  u'Rating': 5,
#  u'UID': 122,
#  u'_id': ObjectId('552be74837902f028450cbb2')}
# {u'ItemID': 5236,
#  u'Rating': 5,
#  u'UID': 782,
#  u'_id': ObjectId('552be74837902f028450cbb3')}
# {u'ItemID': 4324,
#  u'Rating': 5,
#  u'UID': 81,
#  u'_id': ObjectId('552be74837902f028450cbb4')}
# {u'ItemID': 6809,
#  u'Rating': 5,
#  u'UID': 965,
#  u'_id': ObjectId('552be74837902f028450cbb5')}
# {u'ItemID': 2106,
#  u'Rating': 5,
#  u'UID': 64,
#  u'_id': ObjectId('552be74837902f028450cbb6')}
# {u'ItemID': 196,
#  u'Rating': 5,
#  u'UID': 891,
#  u'_id': ObjectId('552be74837902f028450cbb7')}
# {u'ItemID': 5905,
#  u'Rating': 5,
#  u'UID': 751,
#  u'_id': ObjectId('552be74837902f028450cbb8')}
# {u'ItemID': 8152,
#  u'Rating': 5,
#  u'UID': 233,
#  u'_id': ObjectId('552be74837902f028450cbb9')}
# {u'ItemID': 8454,
#  u'Rating': 5,
#  u'UID': 404,
#  u'_id': ObjectId('552be74837902f028450cbba')}
# {u'ItemID': 2504,
#  u'Rating': 5,
#  u'UID': 907,
#  u'_id': ObjectId('552be74837902f028450cbbb')}
# {u'ItemID': 9581,
#  u'Rating': 5,
#  u'UID': 312,
#  u'_id': ObjectId('552be74837902f028450cbbc')}
# {u'ItemID': 634,
#  u'Rating': 5,
#  u'UID': 579,
#  u'_id': ObjectId('552be74837902f028450cbbd')}
# {u'ItemID': 3291,
#  u'Rating': 5,
#  u'UID': 707,
#  u'_id': ObjectId('552be74837902f028450cbbe')}
# {u'ItemID': 1847,
#  u'Rating': 5,
#  u'UID': 345,
#  u'_id': ObjectId('552be74837902f028450cbbf')}
# {u'ItemID': 8291,
#  u'Rating': 5,
#  u'UID': 838,
#  u'_id': ObjectId('552be74837902f028450cbc0')}
# {u'ItemID': 7711,
#  u'Rating': 5,
#  u'UID': 332,
#  u'_id': ObjectId('552be74837902f028450cbc1')}
# {u'ItemID': 5292,
#  u'Rating': 5,
#  u'UID': 703,
#  u'_id': ObjectId('552be74837902f028450cbc2')}
# {u'ItemID': 4681,
#  u'Rating': 5,
#  u'UID': 344,
#  u'_id': ObjectId('552be74837902f028450cbc3')}
# {u'ItemID': 4107,
#  u'Rating': 5,
#  u'UID': 58,
#  u'_id': ObjectId('552be74837902f028450cbc4')}
# {u'ItemID': 9161,
#  u'Rating': 5,
#  u'UID': 328,
#  u'_id': ObjectId('552be74837902f028450cbc5')}
# {u'ItemID': 4327,
#  u'Rating': 5,
#  u'UID': 189,
#  u'_id': ObjectId('552be74837902f028450cbc6')}
# {u'ItemID': 7135,
#  u'Rating': 5,
#  u'UID': 793,
#  u'_id': ObjectId('552be74837902f028450cbc7')}
# {u'ItemID': 7668,
#  u'Rating': 5,
#  u'UID': 82,
#  u'_id': ObjectId('552be74837902f028450cbc8')}
# {u'ItemID': 9744,
#  u'Rating': 5,
#  u'UID': 148,
#  u'_id': ObjectId('552be74837902f028450cbc9')}
# {u'ItemID': 1689,
#  u'Rating': 5,
#  u'UID': 661,
#  u'_id': ObjectId('552be74837902f028450cbca')}
# {u'ItemID': 3356,
#  u'Rating': 5,
#  u'UID': 594,
#  u'_id': ObjectId('552be74837902f028450cbcb')}
# {u'ItemID': 4243,
#  u'Rating': 5,
#  u'UID': 893,
#  u'_id': ObjectId('552be74837902f028450cbcc')}
# {u'ItemID': 7398,
#  u'Rating': 5,
#  u'UID': 470,
#  u'_id': ObjectId('552be74837902f028450cbcd')}
# {u'ItemID': 9544,
#  u'Rating': 5,
#  u'UID': 576,
#  u'_id': ObjectId('552be74837902f028450cbce')}
# {u'ItemID': 105,
#  u'Rating': 5,
#  u'UID': 247,
#  u'_id': ObjectId('552be74837902f028450cbcf')}
# {u'ItemID': 9862,
#  u'Rating': 5,
#  u'UID': 500,
#  u'_id': ObjectId('552be74837902f028450cbd0')}
# {u'ItemID': 305,
#  u'Rating': 5,
#  u'UID': 379,
#  u'_id': ObjectId('552be74837902f028450cbd1')}
# {u'ItemID': 5425,
#  u'Rating': 5,
#  u'UID': 583,
#  u'_id': ObjectId('552be74837902f028450cbd2')}
# {u'ItemID': 3826,
#  u'Rating': 5,
#  u'UID': 599,
#  u'_id': ObjectId('552be74837902f028450cbd3')}
# {u'ItemID': 1517,
#  u'Rating': 5,
#  u'UID': 236,
#  u'_id': ObjectId('552be74837902f028450cbd4')}
# {u'ItemID': 5183,
#  u'Rating': 5,
#  u'UID': 942,
#  u'_id': ObjectId('552be74837902f028450cbd5')}
# {u'ItemID': 5863,
#  u'Rating': 5,
#  u'UID': 901,
#  u'_id': ObjectId('552be74837902f028450cbd6')}
# {u'ItemID': 1743,
#  u'Rating': 5,
#  u'UID': 36,
#  u'_id': ObjectId('552be74837902f028450cbd7')}
# {u'ItemID': 4821,
#  u'Rating': 5,
#  u'UID': 881,
#  u'_id': ObjectId('552be74837902f028450cbd8')}
# {u'ItemID': 5998,
#  u'Rating': 5,
#  u'UID': 760,
#  u'_id': ObjectId('552be74837902f028450cbd9')}
# {u'ItemID': 1048,
#  u'Rating': 5,
#  u'UID': 944,
#  u'_id': ObjectId('552be74837902f028450cbda')}
# {u'ItemID': 5237,
#  u'Rating': 5,
#  u'UID': 855,
#  u'_id': ObjectId('552be74837902f028450cbdb')}
# {u'ItemID': 2605,
#  u'Rating': 5,
#  u'UID': 854,
#  u'_id': ObjectId('552be74837902f028450cbdc')}
# {u'ItemID': 377,
#  u'Rating': 5,
#  u'UID': 190,
#  u'_id': ObjectId('552be74837902f028450cbdd')}
# {u'ItemID': 9113,
#  u'Rating': 5,
#  u'UID': 388,
#  u'_id': ObjectId('552be74837902f028450cbde')}
# {u'ItemID': 1958,
#  u'Rating': 5,
#  u'UID': 750,
#  u'_id': ObjectId('552be74837902f028450cbdf')}
# {u'ItemID': 272,
#  u'Rating': 5,
#  u'UID': 915,
#  u'_id': ObjectId('552be74837902f028450cbe0')}
# {u'ItemID': 4332,
#  u'Rating': 5,
#  u'UID': 957,
#  u'_id': ObjectId('552be74837902f028450cbe1')}
# {u'ItemID': 8635,
#  u'Rating': 5,
#  u'UID': 379,
#  u'_id': ObjectId('552be74837902f028450cbe2')}
# {u'ItemID': 1333,
#  u'Rating': 5,
#  u'UID': 286,
#  u'_id': ObjectId('552be74837902f028450cbe3')}
# {u'ItemID': 4801,
#  u'Rating': 5,
#  u'UID': 574,
#  u'_id': ObjectId('552be74837902f028450cbe4')}
# {u'ItemID': 6979,
#  u'Rating': 5,
#  u'UID': 337,
#  u'_id': ObjectId('552be74837902f028450cbe5')}
# {u'ItemID': 6863,
#  u'Rating': 5,
#  u'UID': 68,
#  u'_id': ObjectId('552be74837902f028450cbe6')}
# {u'ItemID': 2276,
#  u'Rating': 5,
#  u'UID': 769,
#  u'_id': ObjectId('552be74837902f028450cbe7')}
# {u'ItemID': 9135,
#  u'Rating': 5,
#  u'UID': 537,
#  u'_id': ObjectId('552be74837902f028450cbe8')}
# {u'ItemID': 7609,
#  u'Rating': 5,
#  u'UID': 538,
#  u'_id': ObjectId('552be74837902f028450cbe9')}
# {u'ItemID': 9210,
#  u'Rating': 5,
#  u'UID': 700,
#  u'_id': ObjectId('552be74837902f028450cbea')}
# {u'ItemID': 1397,
#  u'Rating': 5,
#  u'UID': 164,
#  u'_id': ObjectId('552be74837902f028450cbeb')}
# {u'ItemID': 6528,
#  u'Rating': 5,
#  u'UID': 78,
#  u'_id': ObjectId('552be74837902f028450cbec')}
# {u'ItemID': 1181,
#  u'Rating': 5,
#  u'UID': 275,
#  u'_id': ObjectId('552be74837902f028450cbed')}
# {u'ItemID': 8274,
#  u'Rating': 5,
#  u'UID': 924,
#  u'_id': ObjectId('552be74837902f028450cbee')}
# {u'ItemID': 637,
#  u'Rating': 5,
#  u'UID': 544,
#  u'_id': ObjectId('552be74837902f028450cbef')}
# {u'ItemID': 4659,
#  u'Rating': 5,
#  u'UID': 643,
#  u'_id': ObjectId('552be74837902f028450cbf0')}
# {u'ItemID': 7259,
#  u'Rating': 5,
#  u'UID': 742,
#  u'_id': ObjectId('552be8cb37902f028450cbf1')}
# {u'ItemID': 1220,
#  u'Rating': 5,
#  u'UID': 493,
#  u'_id': ObjectId('552be8cb37902f028450cbf2')}
# {u'ItemID': 5508,
#  u'Rating': 5,
#  u'UID': 531,
#  u'_id': ObjectId('552be8cb37902f028450cbf3')}
# {u'ItemID': 1096,
#  u'Rating': 5,
#  u'UID': 251,
#  u'_id': ObjectId('552be8cb37902f028450cbf4')}
# {u'ItemID': 7697,
#  u'Rating': 5,
#  u'UID': 748,
#  u'_id': ObjectId('552be8cb37902f028450cbf5')}
# {u'ItemID': 8383,
#  u'Rating': 5,
#  u'UID': 607,
#  u'_id': ObjectId('552be8cb37902f028450cbf6')}
# {u'ItemID': 6447,
#  u'Rating': 5,
#  u'UID': 466,
#  u'_id': ObjectId('552be8cb37902f028450cbf7')}
# {u'ItemID': 3957,
#  u'Rating': 5,
#  u'UID': 65,
#  u'_id': ObjectId('552be8cb37902f028450cbf8')}
# {u'ItemID': 7165,
#  u'Rating': 5,
#  u'UID': 96,
#  u'_id': ObjectId('552be8cb37902f028450cbf9')}
# {u'ItemID': 8325,
#  u'Rating': 5,
#  u'UID': 71,
#  u'_id': ObjectId('552be8cb37902f028450cbfa')}
# {u'ItemID': 8169,
#  u'Rating': 5,
#  u'UID': 494,
#  u'_id': ObjectId('552be8cb37902f028450cbfb')}
# {u'ItemID': 4580,
#  u'Rating': 5,
#  u'UID': 687,
#  u'_id': ObjectId('552be8cb37902f028450cbfc')}
# {u'ItemID': 2447,
#  u'Rating': 5,
#  u'UID': 162,
#  u'_id': ObjectId('552be8cb37902f028450cbfd')}
# {u'ItemID': 4204,
#  u'Rating': 5,
#  u'UID': 970,
#  u'_id': ObjectId('552be8cb37902f028450cbfe')}
# {u'ItemID': 3545,
#  u'Rating': 5,
#  u'UID': 597,
#  u'_id': ObjectId('552be8cb37902f028450cbff')}
# {u'ItemID': 1236,
#  u'Rating': 5,
#  u'UID': 193,
#  u'_id': ObjectId('552be8cb37902f028450cc00')}
# {u'ItemID': 9245,
#  u'Rating': 5,
#  u'UID': 826,
#  u'_id': ObjectId('552be8cb37902f028450cc01')}
# {u'ItemID': 8930,
#  u'Rating': 5,
#  u'UID': 910,
#  u'_id': ObjectId('552be8cb37902f028450cc02')}
# {u'ItemID': 6456,
#  u'Rating': 5,
#  u'UID': 680,
#  u'_id': ObjectId('552be8cb37902f028450cc03')}
# {u'ItemID': 250,
#  u'Rating': 5,
#  u'UID': 403,
#  u'_id': ObjectId('552be8cb37902f028450cc04')}
# {u'ItemID': 3030,
#  u'Rating': 5,
#  u'UID': 410,
#  u'_id': ObjectId('552be8cb37902f028450cc05')}
# {u'ItemID': 9089,
#  u'Rating': 5,
#  u'UID': 493,
#  u'_id': ObjectId('552be8cb37902f028450cc06')}
# {u'ItemID': 7774,
#  u'Rating': 5,
#  u'UID': 931,
#  u'_id': ObjectId('552be8cb37902f028450cc07')}
# {u'ItemID': 7663,
#  u'Rating': 5,
#  u'UID': 572,
#  u'_id': ObjectId('552be8cb37902f028450cc08')}
# {u'ItemID': 4584,
#  u'Rating': 5,
#  u'UID': 256,
#  u'_id': ObjectId('552be8cb37902f028450cc09')}
# {u'ItemID': 2777,
#  u'Rating': 5,
#  u'UID': 244,
#  u'_id': ObjectId('552be8cb37902f028450cc0a')}
# {u'ItemID': 7892,
#  u'Rating': 5,
#  u'UID': 148,
#  u'_id': ObjectId('552be8cb37902f028450cc0b')}
# {u'ItemID': 7371,
#  u'Rating': 5,
#  u'UID': 461,
#  u'_id': ObjectId('552be8cb37902f028450cc0c')}
# {u'ItemID': 3930,
#  u'Rating': 5,
#  u'UID': 188,
#  u'_id': ObjectId('552be8cb37902f028450cc0d')}
# {u'ItemID': 915,
#  u'Rating': 5,
#  u'UID': 306,
#  u'_id': ObjectId('552be8cb37902f028450cc0e')}
# {u'ItemID': 608,
#  u'Rating': 5,
#  u'UID': 157,
#  u'_id': ObjectId('552be8cb37902f028450cc0f')}
# {u'ItemID': 2842,
#  u'Rating': 5,
#  u'UID': 630,
#  u'_id': ObjectId('552be8cb37902f028450cc10')}
# {u'ItemID': 1359,
#  u'Rating': 5,
#  u'UID': 282,
#  u'_id': ObjectId('552be8cb37902f028450cc11')}
# {u'ItemID': 4092,
#  u'Rating': 5,
#  u'UID': 672,
#  u'_id': ObjectId('552be8cb37902f028450cc12')}
# {u'ItemID': 9481,
#  u'Rating': 5,
#  u'UID': 659,
#  u'_id': ObjectId('552be8cb37902f028450cc13')}
# {u'ItemID': 8805,
#  u'Rating': 5,
#  u'UID': 121,
#  u'_id': ObjectId('552be8cb37902f028450cc14')}
# {u'ItemID': 8085,
#  u'Rating': 5,
#  u'UID': 254,
#  u'_id': ObjectId('552be8cb37902f028450cc15')}
# {u'ItemID': 5722,
#  u'Rating': 5,
#  u'UID': 465,
#  u'_id': ObjectId('552be8cb37902f028450cc16')}
# {u'ItemID': 7078,
#  u'Rating': 5,
#  u'UID': 679,
#  u'_id': ObjectId('552be8cb37902f028450cc17')}
# {u'ItemID': 4038,
#  u'Rating': 5,
#  u'UID': 931,
#  u'_id': ObjectId('552be8cb37902f028450cc18')}
# {u'ItemID': 8759,
#  u'Rating': 5,
#  u'UID': 145,
#  u'_id': ObjectId('552be8cb37902f028450cc19')}
# {u'ItemID': 6542,
#  u'Rating': 5,
#  u'UID': 805,
#  u'_id': ObjectId('552be8cb37902f028450cc1a')}
# {u'ItemID': 5914,
#  u'Rating': 5,
#  u'UID': 9,
#  u'_id': ObjectId('552be8cb37902f028450cc1b')}
# {u'ItemID': 1002,
#  u'Rating': 5,
#  u'UID': 48,
#  u'_id': ObjectId('552be8cb37902f028450cc1c')}
# {u'ItemID': 1087,
#  u'Rating': 5,
#  u'UID': 310,
#  u'_id': ObjectId('552be8cb37902f028450cc1d')}
# {u'ItemID': 26,
#  u'Rating': 5,
#  u'UID': 705,
#  u'_id': ObjectId('552be8cb37902f028450cc1e')}
# {u'ItemID': 8260,
#  u'Rating': 5,
#  u'UID': 401,
#  u'_id': ObjectId('552be8cb37902f028450cc1f')}
# {u'ItemID': 3250,
#  u'Rating': 5,
#  u'UID': 297,
#  u'_id': ObjectId('552be8cb37902f028450cc20')}
# {u'ItemID': 585,
#  u'Rating': 5,
#  u'UID': 599
# ,
#  u'_id': ObjectId('552be8cb37902f028450cc21')}
# {u'ItemID': 828,
#  u'Rating': 5,
#  u'UID': 668,
#  u'_id': ObjectId('552be8cb37902f028450cc22')}
# {u'ItemID': 45,
#  u'Rating': 5,
#  u'UID': 733,
#  u'_id': ObjectId('552be8cb37902f028450cc23')}
# {u'ItemID': 6904,
#  u'Rating': 5,
#  u'UID': 773,
#  u'_id': ObjectId('552be8cb37902f028450cc24')}
# {u'ItemID': 9885,
#  u'Rating': 5,
#  u'UID': 589,
#  u'_id': ObjectId('552be8cb37902f028450cc25')}
# {u'ItemID': 8384,
#  u'Rating': 5,
#  u'UID': 113,
#  u'_id': ObjectId('552be8cb37902f028450cc26')}
# {u'ItemID': 7509,
#  u'Rating': 5,
#  u'UID': 570,
#  u'_id': ObjectId('552be8cb37902f028450cc27')}
# {u'ItemID': 8863,
#  u'Rating': 5,
#  u'UID': 333,
#  u'_id': ObjectId('552be8cb37902f028450cc28')}
# {u'ItemID': 3766,
#  u'Rating': 5,
#  u'UID': 252,
#  u'_id': ObjectId('552be8cb37902f028450cc29')}
# {u'ItemID': 4518,
#  u'Rating': 5,
#  u'UID': 422,
#  u'_id': ObjectId('552be8cb37902f028450cc2a')}
# {u'ItemID': 8667,
#  u'Rating': 5,
#  u'UID': 666,
#  u'_id': ObjectId('552be8cb37902f028450cc2b')}
# {u'ItemID': 3118,
#  u'Rating': 5,
#  u'UID': 822,
#  u'_id': ObjectId('552be8cb37902f028450cc2c')}
# {u'ItemID': 8929,
#  u'Rating': 5,
#  u'UID': 784,
#  u'_id': ObjectId('552be8cb37902f028450cc2d')}
# {u'ItemID': 5511,
#  u'Rating': 5,
#  u'UID': 101,
#  u'_id': ObjectId('552be8cb37902f028450cc2e')}
# {u'ItemID': 7955,
#  u'Rating': 5,
#  u'UID': 484,
#  u'_id': ObjectId('552be8cb37902f028450cc2f')}
# {u'ItemID': 6637,
#  u'Rating': 5,
#  u'UID': 150,
#  u'_id': ObjectId('552be8cb37902f028450cc30')}
# {u'ItemID': 9892,
#  u'Rating': 5,
#  u'UID': 806,
#  u'_id': ObjectId('552be8cb37902f028450cc31')}
# {u'ItemID': 7835,
#  u'Rating': 5,
#  u'UID': 483,
#  u'_id': ObjectId('552be8cb37902f028450cc32')}
# {u'ItemID': 2590,
#  u'Rating': 5,
#  u'UID': 528,
#  u'_id': ObjectId('552be8cb37902f028450cc33')}
# {u'ItemID': 7464,
#  u'Rating': 5,
#  u'UID': 492,
#  u'_id': ObjectId('552be8cb37902f028450cc34')}
# {u'ItemID': 9270,
#  u'Rating': 5,
#  u'UID': 181,
#  u'_id': ObjectId('552be8cb37902f028450cc35')}
# {u'ItemID': 2627,
#  u'Rating': 5,
#  u'UID': 187,
#  u'_id': ObjectId('552be8cb37902f028450cc36')}
# {u'ItemID': 344,
#  u'Rating': 5,
#  u'UID': 652,
#  u'_id': ObjectId('552be8cb37902f028450cc37')}
# {u'ItemID': 4223,
#  u'Rating': 5,
#  u'UID': 220,
#  u'_id': ObjectId('552be8cb37902f028450cc38')}
# {u'ItemID': 8815,
#  u'Rating': 5,
#  u'UID': 879,
#  u'_id': ObjectId('552be8cb37902f028450cc39')}
# {u'ItemID': 8584,
#  u'Rating': 5,
#  u'UID': 229,
#  u'_id': ObjectId('552be8cb37902f028450cc3a')}
# {u'ItemID': 9140,
#  u'Rating': 5,
#  u'UID': 547,
#  u'_id': ObjectId('552be8cb37902f028450cc3b')}
# {u'ItemID': 4277,
#  u'Rating': 5,
#  u'UID': 236,
#  u'_id': ObjectId('552be8cb37902f028450cc3c')}
# {u'ItemID': 9553,
#  u'Rating': 5,
#  u'UID': 121,
#  u'_id': ObjectId('552be8cb37902f028450cc3d')}
# {u'ItemID': 6183,
#  u'Rating': 5,
#  u'UID': 2,
#  u'_id': ObjectId('552be8cb37902f028450cc3e')}
# {u'ItemID': 3173,
#  u'Rating': 5,
#  u'UID': 125,
#  u'_id': ObjectId('552be8cb37902f028450cc3f')}
# {u'ItemID': 9442,
#  u'Rating': 5,
#  u'UID': 366,
#  u'_id': ObjectId('552be8cb37902f028450cc40')}
# {u'ItemID': 8100,
#  u'Rating': 5,
#  u'UID': 249,
#  u'_id': ObjectId('552be8cb37902f028450cc41')}
# {u'ItemID': 3953,
#  u'Rating': 5,
#  u'UID': 406,
#  u'_id': ObjectId('552be8cb37902f028450cc42')}
# {u'ItemID': 9690,
#  u'Rating': 5,
#  u'UID': 22,
#  u'_id': ObjectId('552be8cb37902f028450cc43')}
# {u'ItemID': 5200,
#  u'Rating': 5,
#  u'UID': 644,
#  u'_id': ObjectId('552be8cb37902f028450cc44')}
# {u'ItemID': 1634,
#  u'Rating': 5,
#  u'UID': 670,
#  u'_id': ObjectId('552be8cb37902f028450cc45')}
# {u'ItemID': 4410,
#  u'Rating': 5,
#  u'UID': 676,
#  u'_id': ObjectId('552be8cb37902f028450cc46')}
# {u'ItemID': 8571,
#  u'Rating': 5,
#  u'UID': 125,
#  u'_id': ObjectId('552be8cb37902f028450cc47')}
# {u'ItemID': 3142,
#  u'Rating': 5,
#  u'UID': 48,
#  u'_id': ObjectId('552be8cb37902f028450cc48')}
# {u'ItemID': 9940,
#  u'Rating': 5,
#  u'UID': 121,
#  u'_id': ObjectId('552be8cb37902f028450cc49')}
# {u'ItemID': 4908,
#  u'Rating': 5,
#  u'UID': 126,
#  u'_id': ObjectId('552be8cb37902f028450cc4a')}
# {u'ItemID': 3140,
#  u'Rating': 5,
#  u'UID': 228,
#  u'_id': ObjectId('552be8cb37902f028450cc4b')}
# {u'ItemID': 6123,
#  u'Rating': 5,
#  u'UID': 448,
#  u'_id': ObjectId('552be8cb37902f028450cc4c')}
# {u'ItemID': 9150,
#  u'Rating': 5,
#  u'UID': 722,
#  u'_id': ObjectId('552be8cb37902f028450cc4d')}
# {u'ItemID': 520,
#  u'Rating': 5,
#  u'UID': 678,
#  u'_id': ObjectId('552be8cb37902f028450cc4e')}
# {u'ItemID': 6976,
#  u'Rating': 5,
#  u'UID': 457,
#  u'_id': ObjectId('552be8cb37902f028450cc4f')}
# {u'ItemID': 8299,
#  u'Rating': 5,
#  u'UID': 13,
#  u'_id': ObjectId('552be8cb37902f028450cc50')}
# {u'ItemID': 7508,
#  u'Rating': 5,
#  u'UID': 786,
#  u'_id': ObjectId('552be8cb37902f028450cc51')}
# {u'ItemID': 8058,
#  u'Rating': 5,
#  u'UID': 523,
#  u'_id': ObjectId('552be8cb37902f028450cc52')}
# {u'ItemID': 1307,
#  u'Rating': 5,
#  u'UID': 550,
#  u'_id': ObjectId('552be8cb37902f028450cc53')}
# {u'ItemID': 699,
#  u'Rating': 5,
#  u'UID': 188,
#  u'_id': ObjectId('552be8cb37902f028450cc54')}
# {u'ItemID': 5725,
#  u'Rating': 5,
#  u'UID': 435,
#  u'_id': ObjectId('552bebee37902f028450cc56')}
# {u'ItemID': 8096,
#  u'Rating': 5,
#  u'UID': 306,
#  u'_id': ObjectId('552bebee37902f028450cc57')}
# {u'ItemID': 6599,
#  u'Rating': 5,
#  u'UID': 533,
#  u'_id': ObjectId('552bebee37902f028450cc58')}
# {u'ItemID': 7528,
#  u'Rating': 5,
#  u'UID': 554,
#  u'_id': ObjectId('552bebee37902f028450cc59')}
# {u'ItemID': 5919,
#  u'Rating': 5,
#  u'UID': 896,
#  u'_id': ObjectId('552bebee37902f028450cc5a')}
# {u'ItemID': 1814,
#  u'Rating': 5,
#  u'UID': 634,
#  u'_id': ObjectId('552bebee37902f028450cc5b')}
# {u'ItemID': 4505,
#  u'Rating': 5,
#  u'UID': 970,
#  u'_id': ObjectId('552bebee37902f028450cc5c')}
# {u'ItemID': 313,
#  u'Rating': 5,
#  u'UID': 33,
#  u'_id': ObjectId('552bebee37902f028450cc5d')}
# {u'ItemID': 5450,
#  u'Rating': 5,
#  u'UID': 965,
#  u'_id': ObjectId('552bebee37902f028450cc5e')}
# {u'ItemID': 2742,
#  u'Rating': 5,
#  u'UID': 536,
#  u'_id': ObjectId('552bebee37902f028450cc5f')}
# {u'ItemID': 6028,
#  u'Rating': 5,
#  u'UID': 650,
#  u'_id': ObjectId('552bebee37902f028450cc60')}
# {u'ItemID': 9515,
#  u'Rating': 5,
#  u'UID': 590,
#  u'_id': ObjectId('552bebee37902f028450cc61')}
# {u'ItemID': 7331,
#  u'Rating': 5,
#  u'UID': 36,
#  u'_id': ObjectId('552bebee37902f028450cc62')}
# {u'ItemID': 6300,
#  u'Rating': 5,
#  u'UID': 309,
#  u'_id': ObjectId('552bebee37902f028450cc63')}
# {u'ItemID': 9848,
#  u'Rating': 5,
#  u'UID': 617,
#  u'_id': ObjectId('552bebee37902f028450cc64')}
# {u'ItemID': 4820,
#  u'Rating': 5,
#  u'UID': 516,
#  u'_id': ObjectId('552bebee37902f028450cc65')}
# {u'ItemID': 1280,
#  u'Rating': 5,
#  u'UID': 407,
#  u'_id': ObjectId('552bebee37902f028450cc66')}
# {u'ItemID': 4502,
#  u'Rating': 5,
#  u'UID': 669,
#  u'_id': ObjectId('552bebee37902f028450cc67')}
# {u'ItemID': 8912,
#  u'Rating': 5,
#  u'UID': 775,
#  u'_id': ObjectId('552bebee37902f028450cc68')}
# {u'ItemID': 7246,
#  u'Rating': 5,
#  u'UID': 184,
#  u'_id': ObjectId('552bebee37902f028450cc69')}
# {u'ItemID': 5001,
#  u'Rating': 5,
#  u'UID': 448,
#  u'_id': ObjectId('552bebee37902f028450cc6a')}
# {u'ItemID': 3069,
#  u'Rating': 5,
#  u'UID': 952,
#  u'_id': ObjectId('552bebee37902f028450cc6b')}
# {u'ItemID': 2785,
#  u'Rating': 5,
#  u'UID': 656,
#  u'_id': ObjectId('552bebee37902f028450cc6c')}
# {u'ItemID': 7504,
#  u'Rating': 5,
#  u'UID': 670,
#  u'_id': ObjectId('552bebee37902f028450cc6d')}
# {u'ItemID': 1375,
#  u'Rating': 5,
#  u'UID': 61,
#  u'_id': ObjectId('552bebee37902f028450cc6e')}
# {u'ItemID': 350,
#  u'Rating': 5,
#  u'UID': 344,
#  u'_id': ObjectId('552bebee37902f028450cc6f')}
# {u'ItemID': 1123,
#  u'Rating': 5,
#  u'UID': 249,
#  u'_id': ObjectId('552bebee37902f028450cc70')}
# {u'ItemID': 4379,
#  u'Rating': 5,
#  u'UID': 1,
#  u'_id': ObjectId('552bebee37902f028450cc71')}
# {u'ItemID': 9136,
#  u'Rating': 5,
#  u'UID': 320,
#  u'_id': ObjectId('552bebee37902f028450cc72')}
# {u'ItemID': 4851,
#  u'Rating': 5,
#  u'UID': 631,
#  u'_id': ObjectId('552bebee37902f028450cc73')}
# {u'ItemID': 6089,
#  u'Rating': 5,
#  u'UID': 562,
#  u'_id': ObjectId('552bebee37902f028450cc74')}
# {u'ItemID': 6682,
#  u'Rating': 5,
#  u'UID': 609,
#  u'_id': ObjectId('552bebee37902f028450cc75')}
# {u'ItemID': 2684,
#  u'Rating': 5,
#  u'UID': 41,
#  u'_id': ObjectId('552bebee37902f028450cc76')}
# {u'ItemID': 6150,
#  u'Rating': 5,
#  u'UID': 990,
#  u'_id': ObjectId('552bebee37902f028450cc77')}
# {u'ItemID': 5518,
#  u'Rating': 5,
#  u'UID': 176,
#  u'_id': ObjectId('552bebee37902f028450cc78')}
# {u'ItemID': 5978,
#  u'Rating': 5,
#  u'UID': 206,
#  u'_id': ObjectId('552bebee37902f028450cc79')}
# {u'ItemID': 1162,
#  u'Rating': 5,
#  u'UID': 668,
#  u'_id': ObjectId('552bebee37902f028450cc7a')}
# {u'ItemID': 3152,
#  u'Rating': 5,
#  u'UID': 595,
#  u'_id': ObjectId('552bebee37902f028450cc7b')}
# {u'ItemID': 8174,
#  u'Rating': 5,
#  u'UID': 144,
#  u'_id': ObjectId('552bebee37902f028450cc7c')}
# {u'ItemID': 9794,
#  u'Rating': 5,
#  u'UID': 968,
#  u'_id': ObjectId('552bebee37902f028450cc7d')}
# {u'ItemID': 2495,
#  u'Rating': 5,
#  u'UID': 599,
#  u'_id': ObjectId('552bebee37902f028450cc7e')}
# {u'ItemID': 1153,
#  u'Rating': 5,
#  u'UID': 797,
#  u'_id': ObjectId('552bebee37902f028450cc7f')}
# {u'ItemID': 994,
#  u'Rating': 5,
#  u'UID': 816,
#  u'_id': ObjectId('552bebee37902f028450cc80')}
# {u'ItemID': 6443,
#  u'Rating': 5,
#  u'UID': 446,
#  u'_id': ObjectId('552bebee37902f028450cc81')}
# {u'ItemID': 4005,
#  u'Rating': 5,
#  u'UID': 911,
#  u'_id': ObjectId('552bebee37902f028450cc82')}
# {u'ItemID': 8455,
#  u'Rating': 5,
#  u'UID': 295,
#  u'_id': ObjectId('552bebee37902f028450cc83')}
# {u'ItemID': 7825,
#  u'Rating': 5,
#  u'UID': 278,
#  u'_id': ObjectId('552bebee37902f028450cc84')}
# {u'ItemID': 5328,
#  u'Rating': 5,
#  u'UID': 615,
#  u'_id': ObjectId('552bebee37902f028450cc85')}
# {u'ItemID': 6492,
#  u'Rating': 5,
#  u'UID': 810,
#  u'_id': ObjectId('552bebee37902f028450cc86')}
# {u'ItemID': 4942,
#  u'Rating': 5,
#  u'UID': 38,
#  u'_id': ObjectId('552bebee37902f028450cc87')}
# {u'ItemID': 1641,
#  u'Rating': 5,
#  u'UID': 464,
#  u'_id': ObjectId('552bebee37902f028450cc88')}
# {u'ItemID': 4359,
#  u'Rating': 5,
#  u'UID': 510,
#  u'_id': ObjectId('552bebee37902f028450cc89')}
# {u'ItemID': 1895,
#  u'Rating': 5,
#  u'UID': 30,
#  u'_id': ObjectId('552bebee37902f028450cc8a')}
# {u'ItemID': 713,
#  u'Rating': 5,
#  u'UID': 900,
#  u'_id': ObjectId('552bebee37902f028450cc8b')}
# {u'ItemID': 5055,
#  u'Rating': 5,
#  u'UID': 444,
#  u'_id': ObjectId('552bebee37902f028450cc8c')}
# {u'ItemID': 3590,
#  u'Rating': 5,
#  u'UID': 288,
#  u'_id': ObjectId('552bebee37902f028450cc8d')}
# {u'ItemID': 5463,
#  u'Rating': 5,
#  u'UID': 346,
#  u'_id': ObjectId('552bebee37902f028450cc8e')}
# {u'ItemID': 2796,
#  u'Rating': 5,
#  u'UID': 335,
#  u'_id':
# ObjectId('552bebee37902f028450cc8f')}
# {u'ItemID': 605,
#  u'Rating': 5,
#  u'UID': 381,
#  u'_id': ObjectId('552bebee37902f028450cc90')}
# {u'ItemID': 7640,
#  u'Rating': 5,
#  u'UID': 83,
#  u'_id': ObjectId('552bebee37902f028450cc91')}
# {u'ItemID': 1449,
#  u'Rating': 5,
#  u'UID': 239,
#  u'_id': ObjectId('552bebee37902f028450cc92')}
# {u'ItemID': 6466,
#  u'Rating': 5,
#  u'UID': 328,
#  u'_id': ObjectId('552bebee37902f028450cc93')}
# {u'ItemID': 2227,
#  u'Rating': 5,
#  u'UID': 205,
#  u'_id': ObjectId('552bebee37902f028450cc94')}
# {u'ItemID': 6164,
#  u'Rating': 5,
#  u'UID': 556,
#  u'_id': ObjectId('552bebee37902f028450cc95')}
# {u'ItemID': 1497,
#  u'Rating': 5,
#  u'UID': 659,
#  u'_id': ObjectId('552bebee37902f028450cc96')}
# {u'ItemID': 5699,
#  u'Rating': 5,
#  u'UID': 470,
#  u'_id': ObjectId('552bebee37902f028450cc97')}
# {u'ItemID': 7552,
#  u'Rating': 5,
#  u'UID': 584,
#  u'_id': ObjectId('552bebee37902f028450cc98')}
# {u'ItemID': 6028,
#  u'Rating': 5,
#  u'UID': 181,
#  u'_id': ObjectId('552bebee37902f028450cc99')}
# {u'ItemID': 7097,
#  u'Rating': 5,
#  u'UID': 298,
#  u'_id': ObjectId('552bebee37902f028450cc9a')}
# {u'ItemID': 5032,
#  u'Rating': 5,
#  u'UID': 515,
#  u'_id': ObjectId('552bebee37902f028450cc9b')}
# {u'ItemID': 7547,
#  u'Rating': 5,
#  u'UID': 724,
#  u'_id': ObjectId('552bebee37902f028450cc9c')}
# {u'ItemID': 5033,
#  u'Rating': 5,
#  u'UID': 754,
#  u'_id': ObjectId('552bebee37902f028450cc9d')}
# {u'ItemID': 8864,
#  u'Rating': 5,
#  u'UID': 669,
#  u'_id': ObjectId('552bebee37902f028450cc9e')}
# {u'ItemID': 9192,
#  u'Rating': 5,
#  u'UID': 836,
#  u'_id': ObjectId('552bebee37902f028450cc9f')}
# {u'ItemID': 1776,
#  u'Rating': 5,
#  u'UID': 957,
#  u'_id': ObjectId('552bebee37902f028450cca0')}
# {u'ItemID': 7421,
#  u'Rating': 5,
#  u'UID': 619,
#  u'_id': ObjectId('552bebee37902f028450cca1')}
# {u'ItemID': 9401,
#  u'Rating': 5,
#  u'UID': 454,
#  u'_id': ObjectId('552bebee37902f028450cca2')}
# {u'ItemID': 1742,
#  u'Rating': 5,
#  u'UID': 12,
#  u'_id': ObjectId('552bebee37902f028450cca3')}
# {u'ItemID': 4723,
#  u'Rating': 5,
#  u'UID': 319,
#  u'_id': ObjectId('552bebee37902f028450cca4')}
# {u'ItemID': 2523,
#  u'Rating': 5,
#  u'UID': 151,
#  u'_id': ObjectId('552bebee37902f028450cca5')}
# {u'ItemID': 3033,
#  u'Rating': 5,
#  u'UID': 579,
#  u'_id': ObjectId('552bebee37902f028450cca6')}
# {u'ItemID': 9108,
#  u'Rating': 5,
#  u'UID': 206,
#  u'_id': ObjectId('552bebee37902f028450cca7')}
# {u'ItemID': 3920,
#  u'Rating': 5,
#  u'UID': 376,
#  u'_id': ObjectId('552bebee37902f028450cca8')}
# {u'ItemID': 1301,
#  u'Rating': 5,
#  u'UID': 567,
#  u'_id': ObjectId('552bebee37902f028450cca9')}
# {u'ItemID': 1762,
#  u'Rating': 5,
#  u'UID': 791,
#  u'_id': ObjectId('552bebee37902f028450ccaa')}
# {u'ItemID': 4478,
#  u'Rating': 5,
#  u'UID': 193,
#  u'_id': ObjectId('552bebee37902f028450ccab')}
# {u'ItemID': 2871,
#  u'Rating': 5,
#  u'UID': 240,
#  u'_id': ObjectId('552bebee37902f028450ccac')}
# {u'ItemID': 7185,
#  u'Rating': 5,
#  u'UID': 231,
#  u'_id': ObjectId('552bebee37902f028450ccad')}
# {u'ItemID': 7822,
#  u'Rating': 5,
#  u'UID': 545,
#  u'_id': ObjectId('552bebee37902f028450ccae')}
# {u'ItemID': 2682,
#  u'Rating': 5,
#  u'UID': 578,
#  u'_id': ObjectId('552bebee37902f028450ccaf')}
# {u'ItemID': 2259,
#  u'Rating': 5,
#  u'UID': 615,
#  u'_id': ObjectId('552bebee37902f028450ccb0')}
# {u'ItemID': 8591,
#  u'Rating': 5,
#  u'UID': 990,
#  u'_id': ObjectId('552bebee37902f028450ccb1')}
# {u'ItemID': 5063,
#  u'Rating': 5,
#  u'UID': 958,
#  u'_id': ObjectId('552bebee37902f028450ccb2')}
# {u'ItemID': 4282,
#  u'Rating': 5,
#  u'UID': 103,
#  u'_id': ObjectId('552bebee37902f028450ccb3')}
# {u'ItemID': 2849,
#  u'Rating': 5,
#  u'UID': 877,
#  u'_id': ObjectId('552bebee37902f028450ccb4')}
# {u'ItemID': 9032,
#  u'Rating': 5,
#  u'UID': 881,
#  u'_id': ObjectId('552bebee37902f028450ccb5')}
# {u'ItemID': 6938,
#  u'Rating': 5,
#  u'UID': 215,
#  u'_id': ObjectId('552bebee37902f028450ccb6')}
# {u'ItemID': 1301,
#  u'Rating': 5,
#  u'UID': 516,
#  u'_id': ObjectId('552bebee37902f028450ccb7')}
# {u'ItemID': 838,
#  u'Rating': 5,
#  u'UID': 910,
#  u'_id': ObjectId('552bebee37902f028450ccb8')}
# {u'ItemID': 1186,
#  u'Rating': 5,
#  u'UID': 128,
#  u'_id': ObjectId('552bebee37902f028450ccb9')}
# {u'ItemID': 3756,
#  u'Rating': 5,
#  u'UID': 534,
#  u'_id': ObjectId('552bec0837902f028450ccbb')}
# {u'ItemID': 8248,
#  u'Rating': 5,
#  u'UID': 999,
#  u'_id': ObjectId('552bec0837902f028450ccbc')}
# {u'ItemID': 1934,
#  u'Rating': 5,
#  u'UID': 267,
#  u'_id': ObjectId('552bec0837902f028450ccbd')}
# {u'ItemID': 8805,
#  u'Rating': 5,
#  u'UID': 79,
#  u'_id': ObjectId('552bec0837902f028450ccbe')}
# {u'ItemID': 3564,
#  u'Rating': 5,
#  u'UID': 920,
#  u'_id': ObjectId('552bec0837902f028450ccbf')}
# {u'ItemID': 7723,
#  u'Rating': 5,
#  u'UID': 310,
#  u'_id': ObjectId('552bec0837902f028450ccc0')}
# {u'ItemID': 6105,
#  u'Rating': 5,
#  u'UID': 846,
#  u'_id': ObjectId('552bec0837902f028450ccc1')}
# {u'ItemID': 8904,
#  u'Rating': 5,
#  u'UID': 459,
#  u'_id': ObjectId('552bec0837902f028450ccc2')}
# {u'ItemID': 6193,
#  u'Rating': 5,
#  u'UID': 373,
#  u'_id': ObjectId('552bec0837902f028450ccc3')}
# {u'ItemID': 6161,
#  u'Rating': 5,
#  u'UID': 225,
#  u'_id': ObjectId('552bec0837902f028450ccc4')}
# {u'ItemID': 4687,
#  u'Rating': 5,
#  u'UID': 356,
#  u'_id': ObjectId('552bec0837902f028450ccc5')}
# {u'ItemID': 6508,
#  u'Rating': 5,
#  u'UID': 579,
#  u'_id': ObjectId('552bec0837902f028450ccc6')}
# {u'ItemID': 3432,
#  u'Rating': 5,
#  u'UID': 62,
#  u'_id': ObjectId('552bec0837902f028450ccc7')}
# {u'ItemID': 1240,
#  u'Rating': 5,
#  u'UID': 340,
#  u'_id': ObjectId('552bec0837902f028450ccc8')}
# {u'ItemID': 4231,
#  u'Rating': 5,
#  u'UID': 491,
#  u'_id': ObjectId('552bec0837902f028450ccc9')}
# {u'ItemID': 8689,
#  u'Rating': 5,
#  u'UID': 719,
#  u'_id': ObjectId('552bec0837902f028450ccca')}
# {u'ItemID': 5148,
#  u'Rating': 5,
#  u'UID': 834,
#  u'_id': ObjectId('552bec0837902f028450cccb')}
# {u'ItemID': 3284,
#  u'Rating': 5,
#  u'UID': 130,
#  u'_id': ObjectId('552bec0837902f028450cccc')}
# {u'ItemID': 9972,
#  u'Rating': 5,
#  u'UID': 268,
#  u'_id': ObjectId('552bec0837902f028450cccd')}
# {u'ItemID': 176,
#  u'Rating': 5,
#  u'UID': 623,
#  u'_id': ObjectId('552bec0837902f028450ccce')}
# {u'ItemID': 1848,
#  u'Rating': 5,
#  u'UID': 15,
#  u'_id': ObjectId('552bec0837902f028450cccf')}
# {u'ItemID': 3958,
#  u'Rating': 5,
#  u'UID': 412,
#  u'_id': ObjectId('552bec0837902f028450ccd0')}
# {u'ItemID': 691,
#  u'Rating': 5,
#  u'UID': 660,
#  u'_id': ObjectId('552bec0837902f028450ccd1')}
# {u'ItemID': 7818,
#  u'Rating': 5,
#  u'UID': 922,
#  u'_id': ObjectId('552bec0837902f028450ccd2')}
# {u'ItemID': 6725,
#  u'Rating': 5,
#  u'UID': 127,
#  u'_id': ObjectId('552bec0837902f028450ccd3')}
# {u'ItemID': 8114,
#  u'Rating': 5,
#  u'UID': 812,
#  u'_id': ObjectId('552bec0837902f028450ccd4')}
# {u'ItemID': 4409,
#  u'Rating': 5,
#  u'UID': 110,
#  u'_id': ObjectId('552bec0837902f028450ccd5')}
# {u'ItemID': 5260,
#  u'Rating': 5,
#  u'UID': 258,
#  u'_id': ObjectId('552bec0837902f028450ccd6')}
# {u'ItemID': 85,
#  u'Rating': 5,
#  u'UID': 458,
#  u'_id': ObjectId('552bec0837902f028450ccd7')}
# {u'ItemID': 1149,
#  u'Rating': 5,
#  u'UID': 353,
#  u'_id': ObjectId('552bec0837902f028450ccd8')}
# {u'ItemID': 2713,
#  u'Rating': 5,
#  u'UID': 405,
#  u'_id': ObjectId('552bec0837902f028450ccd9')}
# {u'ItemID': 6304,
#  u'Rating': 5,
#  u'UID': 72,
#  u'_id': ObjectId('552bec0837902f028450ccda')}
# {u'ItemID': 1429,
#  u'Rating': 5,
#  u'UID': 802,
#  u'_id': ObjectId('552bec0837902f028450ccdb')}
# {u'ItemID': 6742,
#  u'Rating': 5,
#  u'UID': 551,
#  u'_id': ObjectId('552bec0837902f028450ccdc')}
# {u'ItemID': 2970,
#  u'Rating': 5,
#  u'UID': 792,
#  u'_id': ObjectId('552bec0837902f028450ccdd')}
# {u'ItemID': 6886,
#  u'Rating': 5,
#  u'UID': 364,
#  u'_id': ObjectId('552bec0837902f028450ccde')}
# {u'ItemID': 6161,
#  u'Rating': 5,
#  u'UID': 425,
#  u'_id': ObjectId('552bec0837902f028450ccdf')}
# {u'ItemID': 3318,
#  u'Rating': 5,
#  u'UID': 962,
#  u'_id': ObjectId('552bec0837902f028450cce0')}
# {u'ItemID': 7568,
#  u'Rating': 5,
#  u'UID': 975,
#  u'_id': ObjectId('552bec0837902f028450cce1')}
# {u'ItemID': 1904,
#  u'Rating': 5,
#  u'UID': 9,
#  u'_id': ObjectId('552bec0837902f028450cce2')}
# {u'ItemID': 7646,
#  u'Rating': 5,
#  u'UID': 421,
#  u'_id': ObjectId('552bec0837902f028450cce3')}
# {u'ItemID': 3890,
#  u'Rating': 5,
#  u'UID': 168,
#  u'_id': ObjectId('552bec0837902f028450cce4')}
# {u'ItemID': 5037,
#  u'Rating': 5,
#  u'UID': 459,
#  u'_id': ObjectId('552bec0837902f028450cce5')}
# {u'ItemID': 2389,
#  u'Rating': 5,
#  u'UID': 159,
#  u'_id': ObjectId('552bec0837902f028450cce6')}
# {u'ItemID': 5860,
#  u'Rating': 5,
#  u'UID': 598,
#  u'_id': ObjectId('552bec0837902f028450cce7')}
# {u'ItemID': 3354,
#  u'Rating': 5,
#  u'UID': 935,
#  u'_id': ObjectId('552bec0837902f028450cce8')}
# {u'ItemID': 9246,
#  u'Rating': 5,
#  u'UID': 935,
#  u'_id': ObjectId('552bec0837902f028450cce9')}
# {u'ItemID': 776,
#  u'Rating': 5,
#  u'UID': 296,
#  u'_id': ObjectId('552bec0837902f028450ccea')}
# {u'ItemID': 6747,
#  u'Rating': 5,
#  u'UID': 165,
#  u'_id': ObjectId('552bec0837902f028450cceb')}
# {u'ItemID': 9121,
#  u'Rating': 5,
#  u'UID': 579,
#  u'_id': ObjectId('552bec0837902f028450ccec')}
# {u'ItemID': 2427,
#  u'Rating': 5,
#  u'UID': 107,
#  u'_id': ObjectId('552bec0837902f028450cced')}
# {u'ItemID': 7202,
#  u'Rating': 5,
#  u'UID': 99,
#  u'_id': ObjectId('552bec0837902f028450ccee')}
# {u'ItemID': 114,
#  u'Rating': 5,
#  u'UID': 600,
#  u'_id': ObjectId('552bec0837902f028450ccef')}
# {u'ItemID': 706,
#  u'Rating': 5,
#  u'UID': 276,
#  u'_id': ObjectId('552bec0837902f028450ccf0')}
# {u'ItemID': 323,
#  u'Rating': 5,
#  u'UID': 397,
#  u'_id': ObjectId('552bec0837902f028450ccf1')}
# {u'ItemID': 6899,
#  u'Rating': 5,
#  u'UID': 495,
#  u'_id': ObjectId('552bec0837902f028450ccf2')}
# {u'ItemID': 9832,
#  u'Rating': 5,
#  u'UID': 158,
#  u'_id': ObjectId('552bec0837902f028450ccf3')}
# {u'ItemID': 7462,
#  u'Rating': 5,
#  u'UID': 915,
#  u'_id': ObjectId('552bec0837902f028450ccf4')}
# {u'ItemID': 4805,
#  u'Rating': 5,
#  u'UID': 818,
#  u'_id': ObjectId('552bec0837902f028450ccf5')}
# {u'ItemID': 9628,
#  u'Rating': 5,
#  u'UID': 96,
#  u'_id': ObjectId('552bec0837902f028450ccf6')}
# {u'ItemID': 631,
#  u'Rating': 5,
#  u'UID': 869,
#  u'_id': ObjectId('552bec0837902f028450ccf7')}
# {u'ItemID': 8281,
#  u'Rating': 5,
#  u'UID': 193,
#  u'_id': ObjectId('552bec0837902f028450ccf8')}
# {u'ItemID': 8700,
#  u'Rating': 5,
#  u'UID': 383,
#  u'_id': ObjectId('552bec0837902f028450ccf9')}
# {u'ItemID': 4377,
#  u'Rating': 5,
#  u'UID': 780,
#  u'_id': ObjectId('552bec0837902f028450ccfa')}
# {u'ItemID': 1728,
#  u'Rating': 5,
#  u'UID': 279,
#  u'_id': ObjectId('552bec0837902f028450ccfb')}
# {u'ItemID': 3028,
#  u'Rating': 5,
#  u'UID': 913,
#  u'_id': ObjectId('552bec0837902f028450ccfc')}
# {u'ItemID': 5748,
#  u'Rating': 5,
#  u'UID': 251,
#  u'_id': ObjectId('552bec0837902f028450ccfd')}
# {u'ItemID': 3025,
#  u'Rating': 5,
#  u'UID': 688,
#  u'_id': ObjectId('552bec0837902f028450ccfe')}
# {u'ItemID': 7077,
#  u'Rating': 5,
#  u'UID': 115,
#  u'_id': ObjectId('552bec0837902f028450ccff')}
# {u'ItemID': 5014,
#  u'Rating': 5,
#  u'UID': 879,
#  u'_id': ObjectId('552bec0837902f028450cd00')}
# {u'ItemID': 7785,
#  u'Rating': 5,
#  u'UID': 609,
#  u'_id': ObjectId('552bec0837902f028450cd01')}
# {u'ItemID': 6576,
#  u'Rating': 5,
#  u'UID': 890,
#  u'_id': ObjectId('552bec0837902f028450cd02')}
# {u'ItemID': 420,
#  u'Rating': 5,
#  u'UID': 20,
#  u'_id': ObjectId('552bec0837902f028450cd03')}
# {u'ItemID': 7535,
#  u'Rating': 5,
#  u'UID': 828,
#  u'_id': ObjectId('552bec0837902f028450cd04')}
# {u'ItemID': 6239,
#  u'Rating': 5,
#  u'UID': 82,
#  u'_id': ObjectId('552bec0837902f028450cd05')}
# {u'ItemID': 5110,
#  u'Rating': 5,
#  u'UID': 623,
#  u'_id': ObjectId('552bec0837902f028450cd06')}
# {u'ItemID': 2092,
#  u'Rating': 5,
#  u'UID': 934,
#  u'_id': ObjectId('552bec0837902f028450cd07')}
# {u'ItemID': 9549,
#  u'Rating': 5,
#  u'UID': 54,
#  u'_id': ObjectId('552bec0837902f028450cd08')}
# {u'ItemID': 1251,
#  u'Rating': 5,
#  u'UID': 54,
#  u'_id': ObjectId('552bec0837902f028450cd09')}
# {u'ItemID': 8166,
#  u'Rating': 5,
#  u'UID': 173,
#  u'_id': ObjectId('552bec0837902f028450cd0a')}
# {u'ItemID': 6113,
#  u'Rating': 5,
#  u'UID': 251,
#  u'_id': ObjectId('552bec0837902f028450cd0b')}
# {u'ItemID': 387,
#  u'Rating': 5,
#  u'UID': 356,
#  u'_id': ObjectId('552bec0837902f028450cd0c')}
# {u'ItemID': 6382,
#  u'Rating': 5,
#  u'UID': 465,
#  u'_id': ObjectId('552bec0837902f028450cd0d')}
# {u'ItemID': 9790,
#  u'Rating': 5,
#  u'UID': 575,
#  u'_id': ObjectId('552bec0837902f028450cd0e')}
# {u'ItemID': 1319,
#  u'Rating': 5,
#  u'UID': 519,
#  u'_id': ObjectId('552bec0837902f028450cd0f')}
# {u'ItemID': 1473,
#  u'Rating': 5,
#  u'UID': 323,
#  u'_id': ObjectId('552bec0837902f028450cd10')}
# {u'ItemID': 4239,
#  u'Rating': 5,
#  u'UID': 716,
#  u'_id': ObjectId('552bec0837902f028450cd11')}
# {u'ItemID': 7869,
#  u'Rating': 5,
#  u'UID': 70,
#  u'_id': ObjectId('552bec0837902f028450cd12')}
# {u'ItemID': 9288,
#  u'Rating': 5,
#  u'UID': 209,
#  u'_id': ObjectId('552bec0837902f028450cd13')}
# {u'ItemID': 8938,
#  u'Rating': 5,
#  u'UID': 644,
#  u'_id': ObjectId('552bec0837902f028450cd14')}
# {u'ItemID': 2386,
#  u'Rating': 5,
#  u'UID': 895,
#  u'_id': ObjectId('552bec0837902f028450cd15')}
# {u'ItemID': 462,
#  u'Rating': 5,
#  u'UID': 234,
#  u'_id': ObjectId('552bec0837902f028450cd16')}
# {u'ItemID': 1602,
#  u'Rating': 5,
#  u'UID': 334,
#  u'_id': ObjectId('552bec0837902f028450cd17')}
# {u'ItemID': 4590,
#  u'Rating': 5,
#  u'UID': 440,
#  u'_id': ObjectId('552bec0837902f028450cd18')}
# {u'ItemID': 8144,
#  u'Rating': 5,
#  u'UID': 798,
#  u'_id': ObjectId('552bec0837902f028450cd19')}
# {u'ItemID': 8233,
#  u'Rating': 5,
#  u'UID': 171,
#  u'_id': ObjectId('552bec0837902f028450cd1a')}
# {u'ItemID': 5734,
#  u'Rating': 5,
#  u'UID': 816,
#  u'_id': ObjectId('552bec0837902f028450cd1b')}
# {u'ItemID': 2394,
#  u'Rating': 5,
#  u'UID': 849,
#  u'_id': ObjectId('552bec0837902f028450cd1c')}
# {u'ItemID': 2865,
#  u'Rating': 5,
#  u'UID': 748,
#  u'_id': ObjectId('552bec0837902f028450cd1d')}
# {u'ItemID': 2915,
#  u'Rating': 5,
#  u'UID': 8,
#  u'_id': ObjectId('552bec0837902f028450cd1e')}
# '\nrating_remove_all()\n'

# %% [markdown]
# #the next function need to be implement is the output db.rating to the graphlab in csv format

# %%
import csv
def rating_output_csv(db):
    """input:
        db.collection.collection
       output:
        the csv path in the system with csv containing UID, ItemID, Rating
    """
    query ={"_id":{"$exists":1}}
    projection ={"_id":0,"UID":1,"ItemID":1,"Rating":1}
    ratings = db.rating.find(query,projection)
    
    with open('rating.csv', 'wb') as csvfile:
        ratingwriter = csv.writer(csvfile)
        ratingwriter.writerow(['UID','ItemID','Rating'])
        for a in ratings:
            ratingwriter.writerow([a["UID"],a["ItemID"],a["Rating"]])
        
    #print type(csvfile)
rating_output_csv(db)

# %% [markdown]
# #Generate a random rating table for test

# %%
import random
def gen_rating(k):
    """input:
    k  is the number of row in the rating collection
    output:
    random table for UID, ItemID, Rating
    rating is within 0-5.
    """
    userids = range(1000)
    itemids = range(10000)
    rating = range(6)
    for i in range(k):
        uid = random.choice(userids)
        itemid = random.choice(itemids)
        user_rating = random.choice(rating)
        rating_create(uid,itemid,user_rating)
    
gen_rating(100)
rating_output_csv(db)
# Out:
# done

# %% [markdown]
# # I decide to use flask to perform AJAX (since the backend is now in python)

# %%
def test():
    """
    this is a test for user 2, ingest item data to the db.item
    """
    itemID = 1814
    url ="http://www.amazon.com/1989-Taylor-Swift/dp/B00MRHANNI/ref=pd_sim_m_3?ie=UTF8&refRID=1K8Y170G44FNQP6RA2H5" 
    tn = "http://ecx.images-amazon.com/images/I/41q3uhpDctL._AA160_.jpg"

    item_create(itemID,url,tn)
    ['1814', '6089', '2447', '4005', '4410']

    itemID = 6089
    tn ="http://ecx.images-amazon.com/images/I/61J61fwud1L._AA160_.jpg"
    url="http://www.amazon.com/Cheek-Deluxe-Lady-Gaga/dp/B00MU79IL8/ref=sr_1_1?ie=UTF8&qid=1428964029&sr=8-1&keywords=lady+gaga"
    item_create(itemID,url,tn)

    itemID = 2447
    tn ="http://ecx.images-amazon.com/images/I/616y3gmSmcL._AA160_.jpg"
    url="http://www.amazon.com/The-Lonely-Hour-Deluxe-Edition/dp/B00H3GZMIE/ref=pd_sim_m_2?ie=UTF8&refRID=1G47A5BAXVTPENQKE6AJ"
    item_create(itemID,url,tn)

    itemID = 4005
    tn ="http://ecx.images-amazon.com/images/I/613BBVSBnEL._AA160_.jpg"
    url="http://www.amazon.com/Hybrid-Theory-LINKIN-PARK/dp/B00004Z459/ref=sr_1_1?ie=UTF8&qid=1428964399&sr=8-1&keywords=linkin+park"
    item_create(itemID,url,tn)
    
    itemID = 4410
    tn ="http://ecx.images-amazon.com/images/I/41yfeQmnysL._SX350_PI_PJStripe-Prime-Only-500px,TopLeft,0,0_AA160_.jpg"
    url="http://www.amazon.com/Hunting-Party-Linkin-Park/dp/B00JYKU6BK/ref=sr_1_2?ie=UTF8&qid=1428964432&sr=8-2&keywords=linkin+park"
    item_create(itemID,url,tn)

# %%
test()
